# %%
#Add Imports
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#Load CSV file
cmpd_violent_crimes = pd.read_csv('cmpd_violent_cleaned_data_df')

# %%
#Check File
cmpd_violent_crimes.head()
# Out:
#    Unnamed: 0 Unnamed: 0.1  Aggravated Assault-Fists,Feet, etc.  \
# 0           0     1/1/2015                                   11
# 1           1     2/1/2015                                    3
# 2           2     3/1/2015                                    8
# 3           3     4/1/2015                                   12
# 4           4     5/1/2015                                   10
#
#    Aggravated Assault-Gun  Aggravated Assault-Knife  \
# 0                     237                        41
# 1                     134                        40
# 2                     141                        48
# 3                     132                        54
# 4                     174                        71
#
#    Aggravated Assault-Other Weapon  Armed Robbery  Attempted Rape  Homicide  \
# 0                               40             99             0.0         8
# 1                               46             67             1.0         5
# ...

# %%
cmpd_violent_crimes.describe()
# Out:
#        Unnamed: 0  Aggravated Assault-Fists,Feet, etc.  \
# count   96.000000                            96.000000
# mean    47.500000                            10.739583
# std     27.856777                             3.578429
# min      0.000000                             3.000000
# 25%     23.750000                             8.000000
# 50%     47.500000                            11.000000
# 75%     71.250000                            13.000000
# max     95.000000                            21.000000
#
#        Aggravated Assault-Gun  Aggravated Assault-Knife  \
# count               96.000000                 96.000000
# mean               272.729167                 46.604167
# std                 90.410465                  9.305889
# min                128.000000                 23.000000
# 25%                209.000000                 40.000000
# 50%                257.000000                 45.000000
# 75%                323.000000                 52.000000
# ...

# %%
cmpd_violent_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           96 non-null     int64
#  1   Unnamed: 0.1                         96 non-null     object
#  2   Aggravated Assault-Fists,Feet, etc.  96 non-null     int64
#  3   Aggravated Assault-Gun               96 non-null     int64
#  4   Aggravated Assault-Knife             96 non-null     int64
#  5   Aggravated Assault-Other Weapon      96 non-null     int64
#  6   Armed Robbery                        96 non-null     int64
#  7   Attempted Rape                       96 non-null     float64
#  8   Homicide                             96 non-null     int64
#  9   Non-Fatal Gunshot Injury             96 non-null     int64
#  10  Rape                                 96 non-null     int64
# ...

# %%
#Create the test independent and dependent values

x= cmpd_violent_crimes.iloc[:, 0].values.reshape(-1,1)
y= cmpd_violent_crimes.iloc[:,13].values.reshape(-1,1)

# %%
Violent_linear_regressor = LinearRegression()

# %%
Violent_linear_regressor.fit(x,y)
# Out:
# LinearRegression()

# %%
crime_pred = Violent_linear_regressor.predict(x)

# %%
plt.scatter(x, y)
plt.plot(x, crime_pred, color='red')
plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,y_train, y_test = train_test_split(x,y,random_state=1,stratify=y)

x_train.shape
