# %%
# %matplotlib inline

# Dependencies

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Files to load
cmpd_data_to_load = "CMPD_Incidents.csv"

# %%
# Read the city data file and store it in a pandas DataFrame.
cmpd_data_df = pd.read_csv(cmpd_data_to_load)
cmpd_data_df.head(5)
# Out:
# /var/folders/qm/j46d3dtj50179gnjc9c9m_2c0000gn/T/ipykernel_66835/1442070803.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   cmpd_data_df = pd.read_csv(cmpd_data_to_load)
#               X              Y  YEAR INCIDENT_REPORT_ID             LOCATION  \
# 0  1.458768e+06  470012.000130  2023   20230130-2148-03     8400 DIANTHUS CT
# 1  1.446976e+06  582067.000101  2023   20230130-2016-02     4200 NAPA OAK DR
# 2  1.449721e+06  543940.999909  2023   20230130-1859-01         300 W 6TH ST
# 3  1.478341e+06  518314.999980  2023   20230130-1858-00  7400 PEBBLESTONE DR
# 4  1.439082e+06  510351.000160  2023   20230130-1820-02        7100 SOUTH BV
#
#         CITY STATE      ZIP  X_COORD_PUBLIC  Y_COORD_PUBLIC  ...  \
# 0  CHARLOTTE    NC      NaN       1458768.0        470012.0  ...
# 1  CHARLOTTE    NC  28216.0       1446976.0        582067.0  ...
# 2  CHARLOTTE    NC  28202.0       1449721.0        543941.0  ...
# ...

# %%
# Get the columns and the rows that are not null.
cmpd_data_df.count()
# Out:
# X                            537801
# Y                            537801
# YEAR                         557713
# INCIDENT_REPORT_ID           557713
# LOCATION                     557713
# CITY                         557713
# STATE                        557709
# ZIP                          384319
# X_COORD_PUBLIC               537801
# Y_COORD_PUBLIC               537801
# LATITUDE_PUBLIC              537801
# LONGITUDE_PUBLIC             537801
# DIVISION_ID                  557713
# CMPD_PATROL_DIVISION         556888
# NPA                          557713
# DATE_REPORTED                557713
# DATE_INCIDENT_BEGAN          557713
# DATE_INCIDENT_END            416938
# ADDRESS_DESCRIPTION          557710
# LOCATION_TYPE_DESCRIPTION    557712
# PLACE_TYPE_DESCRIPTION       557713
# PLACE_DETAIL_DESCRIPTION     557713
# CLEARANCE_STATUS             557713
# CLEARANCE_DETAIL_STATUS      557713
# CLEARANCE_DATE               228499
# HIGHEST_NIBRS_CODE           557713
# ...

# %%
# Get the columns and the rows that are not null.
cmpd_data_df.isnull().sum()
# Out:
# X                             19912
# Y                             19912
# YEAR                              0
# INCIDENT_REPORT_ID                0
# LOCATION                          0
# CITY                              0
# STATE                             4
# ZIP                          173394
# X_COORD_PUBLIC                19912
# Y_COORD_PUBLIC                19912
# LATITUDE_PUBLIC               19912
# LONGITUDE_PUBLIC              19912
# DIVISION_ID                       0
# CMPD_PATROL_DIVISION            825
# NPA                               0
# DATE_REPORTED                     0
# DATE_INCIDENT_BEGAN               0
# DATE_INCIDENT_END            140775
# ADDRESS_DESCRIPTION               3
# LOCATION_TYPE_DESCRIPTION         1
# PLACE_TYPE_DESCRIPTION            0
# PLACE_DETAIL_DESCRIPTION          0
# CLEARANCE_STATUS                  0
# CLEARANCE_DETAIL_STATUS           0
# CLEARANCE_DATE               329214
# HIGHEST_NIBRS_CODE                0
# ...

# %%
# Check for duplicated rows
cmpd_data_df.duplicated().sum()
# Out:
# 0

# %%
# Get the data types of each column.
cmpd_data_df.dtypes
# Out:
# X                            float64
# Y                            float64
# YEAR                           int64
# INCIDENT_REPORT_ID            object
# LOCATION                      object
# CITY                          object
# STATE                         object
# ZIP                           object
# X_COORD_PUBLIC               float64
# Y_COORD_PUBLIC               float64
# LATITUDE_PUBLIC              float64
# LONGITUDE_PUBLIC             float64
# DIVISION_ID                   object
# CMPD_PATROL_DIVISION          object
# NPA                            int64
# DATE_REPORTED                 object
# DATE_INCIDENT_BEGAN           object
# DATE_INCIDENT_END             object
# ADDRESS_DESCRIPTION           object
# LOCATION_TYPE_DESCRIPTION     object
# PLACE_TYPE_DESCRIPTION        object
# PLACE_DETAIL_DESCRIPTION      object
# CLEARANCE_STATUS              object
# CLEARANCE_DETAIL_STATUS       object
# CLEARANCE_DATE                object
# ...

# %%
cmpd_data_df = cmpd_data_df.drop('ZIP', axis = 1)
cmpd_data_df.head(3)
# Out:
#               X              Y  YEAR INCIDENT_REPORT_ID          LOCATION  \
# 0  1.458768e+06  470012.000130  2023   20230130-2148-03  8400 DIANTHUS CT
# 1  1.446976e+06  582067.000101  2023   20230130-2016-02  4200 NAPA OAK DR
# 2  1.449721e+06  543940.999909  2023   20230130-1859-01      300 W 6TH ST
#
#         CITY STATE  X_COORD_PUBLIC  Y_COORD_PUBLIC  LATITUDE_PUBLIC  ...  \
# 0  CHARLOTTE    NC       1458768.0        470012.0        35.027901  ...
# 1  CHARLOTTE    NC       1446976.0        582067.0        35.335142  ...
# 2  CHARLOTTE    NC       1449721.0        543941.0        35.230544  ...
#
#    PLACE_TYPE_DESCRIPTION      PLACE_DETAIL_DESCRIPTION   CLEARANCE_STATUS  \
# 0             Residential  Apartment/Duplex Private Res               Open
# 1             Residential  Apartment/Duplex Private Res               Open
# 2                  Retail     Grocery Store/Supermarket  Cleared by Arrest
#
# ...

# %%
#df raw count
cmpd_data_df.count()
# Out:
# X                            537801
# Y                            537801
# YEAR                         557713
# INCIDENT_REPORT_ID           557713
# LOCATION                     557713
# CITY                         557713
# STATE                        557709
# X_COORD_PUBLIC               537801
# Y_COORD_PUBLIC               537801
# LATITUDE_PUBLIC              537801
# LONGITUDE_PUBLIC             537801
# DIVISION_ID                  557713
# CMPD_PATROL_DIVISION         556888
# NPA                          557713
# DATE_REPORTED                557713
# DATE_INCIDENT_BEGAN          557713
# DATE_INCIDENT_END            416938
# ADDRESS_DESCRIPTION          557710
# LOCATION_TYPE_DESCRIPTION    557712
# PLACE_TYPE_DESCRIPTION       557713
# PLACE_DETAIL_DESCRIPTION     557713
# CLEARANCE_STATUS             557713
# CLEARANCE_DETAIL_STATUS      557713
# CLEARANCE_DATE               228499
# HIGHEST_NIBRS_CODE           557713
# HIGHEST_NIBRS_DESCRIPTION    557713
# ...

# %%
# Get the columns and the rows that are null.
cmpd_data_df.isnull().sum()
# Out:
# X                             19912
# Y                             19912
# YEAR                              0
# INCIDENT_REPORT_ID                0
# LOCATION                          0
# CITY                              0
# STATE                             4
# X_COORD_PUBLIC                19912
# Y_COORD_PUBLIC                19912
# LATITUDE_PUBLIC               19912
# LONGITUDE_PUBLIC              19912
# DIVISION_ID                       0
# CMPD_PATROL_DIVISION            825
# NPA                               0
# DATE_REPORTED                     0
# DATE_INCIDENT_BEGAN               0
# DATE_INCIDENT_END            140775
# ADDRESS_DESCRIPTION               3
# LOCATION_TYPE_DESCRIPTION         1
# PLACE_TYPE_DESCRIPTION            0
# PLACE_DETAIL_DESCRIPTION          0
# CLEARANCE_STATUS                  0
# CLEARANCE_DETAIL_STATUS           0
# CLEARANCE_DATE               329214
# HIGHEST_NIBRS_CODE                0
# HIGHEST_NIBRS_DESCRIPTION         0
# ...

# %%
cmpd_data_df.head(2)
# Out:
#               X              Y  YEAR INCIDENT_REPORT_ID          LOCATION  \
# 0  1.458768e+06  470012.000130  2023   20230130-2148-03  8400 DIANTHUS CT
# 1  1.446976e+06  582067.000101  2023   20230130-2016-02  4200 NAPA OAK DR
#
#         CITY STATE  X_COORD_PUBLIC  Y_COORD_PUBLIC  LATITUDE_PUBLIC  ...  \
# 0  CHARLOTTE    NC       1458768.0        470012.0        35.027901  ...
# 1  CHARLOTTE    NC       1446976.0        582067.0        35.335142  ...
#
#    PLACE_TYPE_DESCRIPTION      PLACE_DETAIL_DESCRIPTION CLEARANCE_STATUS  \
# 0             Residential  Apartment/Duplex Private Res             Open
# 1             Residential  Apartment/Duplex Private Res             Open
#
#    CLEARANCE_DETAIL_STATUS CLEARANCE_DATE HIGHEST_NIBRS_CODE  \
# 0                     Open            NaN                899
# 1                     Open            NaN                240
#
#      HIGHEST_NIBRS_DESCRIPTION OBJECTID  \
# 0  Other Unlisted Non-Criminal        1
# ...

# %%
#cmpd_data_df = cmpd_data_df.drop(columns = ['CLEARANCE_DETAIL_STATUS'])
#cmpd_data_df.head(3)

# %%
cmpd_data_df.isna().sum()
# Out:
# X                             19912
# Y                             19912
# YEAR                              0
# INCIDENT_REPORT_ID                0
# LOCATION                          0
# CITY                              0
# STATE                             4
# X_COORD_PUBLIC                19912
# Y_COORD_PUBLIC                19912
# LATITUDE_PUBLIC               19912
# LONGITUDE_PUBLIC              19912
# DIVISION_ID                       0
# CMPD_PATROL_DIVISION            825
# NPA                               0
# DATE_REPORTED                     0
# DATE_INCIDENT_BEGAN               0
# DATE_INCIDENT_END            140775
# ADDRESS_DESCRIPTION               3
# LOCATION_TYPE_DESCRIPTION         1
# PLACE_TYPE_DESCRIPTION            0
# PLACE_DETAIL_DESCRIPTION          0
# CLEARANCE_STATUS                  0
# CLEARANCE_DETAIL_STATUS           0
# CLEARANCE_DATE               329214
# HIGHEST_NIBRS_CODE                0
# HIGHEST_NIBRS_DESCRIPTION         0
# ...

# %%
cmpd_data_df = cmpd_data_df.drop('Shape', axis = 1)
cmpd_data_df = cmpd_data_df.drop('DATE_INCIDENT_END', axis = 1)
cmpd_data_df = cmpd_data_df.drop('CLEARANCE_DATE', axis = 1)
cmpd_data_df.head(3)
# Out:
#               X              Y  YEAR INCIDENT_REPORT_ID          LOCATION  \
# 0  1.458768e+06  470012.000130  2023   20230130-2148-03  8400 DIANTHUS CT
# 1  1.446976e+06  582067.000101  2023   20230130-2016-02  4200 NAPA OAK DR
# 2  1.449721e+06  543940.999909  2023   20230130-1859-01      300 W 6TH ST
#
#         CITY STATE  X_COORD_PUBLIC  Y_COORD_PUBLIC  LATITUDE_PUBLIC  ...  \
# 0  CHARLOTTE    NC       1458768.0        470012.0        35.027901  ...
# 1  CHARLOTTE    NC       1446976.0        582067.0        35.335142  ...
# 2  CHARLOTTE    NC       1449721.0        543941.0        35.230544  ...
#
#       ADDRESS_DESCRIPTION LOCATION_TYPE_DESCRIPTION PLACE_TYPE_DESCRIPTION  \
# 0  Location of occurrence                   Indoors            Residential
# 1  Location of occurrence               Parking Lot            Residential
# 2  Location of occurrence                   Indoors                 Retail
#
# ...

# %%
cmpd_data_df.isna().sum()
# Out:
# X                            19912
# Y                            19912
# YEAR                             0
# INCIDENT_REPORT_ID               0
# LOCATION                         0
# CITY                             0
# STATE                            4
# X_COORD_PUBLIC               19912
# Y_COORD_PUBLIC               19912
# LATITUDE_PUBLIC              19912
# LONGITUDE_PUBLIC             19912
# DIVISION_ID                      0
# CMPD_PATROL_DIVISION           825
# NPA                              0
# DATE_REPORTED                    0
# DATE_INCIDENT_BEGAN              0
# ADDRESS_DESCRIPTION              3
# LOCATION_TYPE_DESCRIPTION        1
# PLACE_TYPE_DESCRIPTION           0
# PLACE_DETAIL_DESCRIPTION         0
# CLEARANCE_STATUS                 0
# CLEARANCE_DETAIL_STATUS          0
# HIGHEST_NIBRS_CODE               0
# HIGHEST_NIBRS_DESCRIPTION        0
# OBJECTID                         0
# GlobalID                         0
# dtype: int64

# %%
cmpd_data_df = cmpd_data_df.dropna(subset = ['X_COORD_PUBLIC','Y_COORD_PUBLIC'])
cmpd_data_df.isna().sum()
# Out:
# X                              0
# Y                              0
# YEAR                           0
# INCIDENT_REPORT_ID             0
# LOCATION                       0
# CITY                           0
# STATE                          3
# X_COORD_PUBLIC                 0
# Y_COORD_PUBLIC                 0
# LATITUDE_PUBLIC                0
# LONGITUDE_PUBLIC               0
# DIVISION_ID                    0
# CMPD_PATROL_DIVISION         501
# NPA                            0
# DATE_REPORTED                  0
# DATE_INCIDENT_BEGAN            0
# ADDRESS_DESCRIPTION            3
# LOCATION_TYPE_DESCRIPTION      0
# PLACE_TYPE_DESCRIPTION         0
# PLACE_DETAIL_DESCRIPTION       0
# CLEARANCE_STATUS               0
# CLEARANCE_DETAIL_STATUS        0
# HIGHEST_NIBRS_CODE             0
# HIGHEST_NIBRS_DESCRIPTION      0
# OBJECTID                       0
# GlobalID                       0
# dtype: int64

# %%
cmpd_data_df.head(3)
# Out:
#               X              Y  YEAR INCIDENT_REPORT_ID          LOCATION  \
# 0  1.458768e+06  470012.000130  2023   20230130-2148-03  8400 DIANTHUS CT
# 1  1.446976e+06  582067.000101  2023   20230130-2016-02  4200 NAPA OAK DR
# 2  1.449721e+06  543940.999909  2023   20230130-1859-01      300 W 6TH ST
#
#         CITY STATE  X_COORD_PUBLIC  Y_COORD_PUBLIC  LATITUDE_PUBLIC  ...  \
# 0  CHARLOTTE    NC       1458768.0        470012.0        35.027901  ...
# 1  CHARLOTTE    NC       1446976.0        582067.0        35.335142  ...
# 2  CHARLOTTE    NC       1449721.0        543941.0        35.230544  ...
#
#       ADDRESS_DESCRIPTION LOCATION_TYPE_DESCRIPTION PLACE_TYPE_DESCRIPTION  \
# 0  Location of occurrence                   Indoors            Residential
# 1  Location of occurrence               Parking Lot            Residential
# 2  Location of occurrence                   Indoors                 Retail
#
# ...

# %%
cmpd_data_df_clean = cmpd_data_df

# %%
cmpd_data_df_clean.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 cmpd_data_df_clean.type()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'type'
