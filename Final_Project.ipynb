# %%
# %matplotlib inline

# Dependencies

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Files to load
cmpd_data_to_load = "CMPD_Incidents.csv"

# %%
# Read the city data file and store it in a pandas DataFrame.
cmpd_data_df = pd.read_csv(cmpd_data_to_load)
cmpd_data_df.head(5)
# Out:
# /var/folders/qm/j46d3dtj50179gnjc9c9m_2c0000gn/T/ipykernel_5949/1442070803.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   cmpd_data_df = pd.read_csv(cmpd_data_to_load)
#               X              Y  YEAR INCIDENT_REPORT_ID             LOCATION  \
# 0  1.458768e+06  470012.000130  2023   20230130-2148-03     8400 DIANTHUS CT
# 1  1.446976e+06  582067.000101  2023   20230130-2016-02     4200 NAPA OAK DR
# 2  1.449721e+06  543940.999909  2023   20230130-1859-01         300 W 6TH ST
# 3  1.478341e+06  518314.999980  2023   20230130-1858-00  7400 PEBBLESTONE DR
# 4  1.439082e+06  510351.000160  2023   20230130-1820-02        7100 SOUTH BV
#
#         CITY STATE      ZIP  X_COORD_PUBLIC  Y_COORD_PUBLIC  ...  \
# 0  CHARLOTTE    NC      NaN       1458768.0        470012.0  ...
# 1  CHARLOTTE    NC  28216.0       1446976.0        582067.0  ...
# 2  CHARLOTTE    NC  28202.0       1449721.0        543941.0  ...
# ...

# %%
# Get the columns and the rows that are not null.
cmpd_data_df.count()
# Out:
# X                            537801
# Y                            537801
# YEAR                         557713
# INCIDENT_REPORT_ID           557713
# LOCATION                     557713
# CITY                         557713
# STATE                        557709
# ZIP                          384319
# X_COORD_PUBLIC               537801
# Y_COORD_PUBLIC               537801
# LATITUDE_PUBLIC              537801
# LONGITUDE_PUBLIC             537801
# DIVISION_ID                  557713
# CMPD_PATROL_DIVISION         556888
# NPA                          557713
# DATE_REPORTED                557713
# DATE_INCIDENT_BEGAN          557713
# DATE_INCIDENT_END            416938
# ADDRESS_DESCRIPTION          557710
# LOCATION_TYPE_DESCRIPTION    557712
# PLACE_TYPE_DESCRIPTION       557713
# PLACE_DETAIL_DESCRIPTION     557713
# CLEARANCE_STATUS             557713
# CLEARANCE_DETAIL_STATUS      557713
# CLEARANCE_DATE               228499
# HIGHEST_NIBRS_CODE           557713
# ...

# %%
# Get the columns and the rows that are not null.
cmpd_data_df.isnull().sum()
# Out:
# X                             19912
# Y                             19912
# YEAR                              0
# INCIDENT_REPORT_ID                0
# LOCATION                          0
# CITY                              0
# STATE                             4
# ZIP                          173394
# X_COORD_PUBLIC                19912
# Y_COORD_PUBLIC                19912
# LATITUDE_PUBLIC               19912
# LONGITUDE_PUBLIC              19912
# DIVISION_ID                       0
# CMPD_PATROL_DIVISION            825
# NPA                               0
# DATE_REPORTED                     0
# DATE_INCIDENT_BEGAN               0
# DATE_INCIDENT_END            140775
# ADDRESS_DESCRIPTION               3
# LOCATION_TYPE_DESCRIPTION         1
# PLACE_TYPE_DESCRIPTION            0
# PLACE_DETAIL_DESCRIPTION          0
# CLEARANCE_STATUS                  0
# CLEARANCE_DETAIL_STATUS           0
# CLEARANCE_DATE               329214
# HIGHEST_NIBRS_CODE                0
# ...

# %%
# Check for duplicated rows
cmpd_data_df.duplicated().sum()
# Out:
# 0

# %%
# Get the data types of each column.
cmpd_data_df.dtypes
# Out:
# X                            float64
# Y                            float64
# YEAR                           int64
# INCIDENT_REPORT_ID            object
# LOCATION                      object
# CITY                          object
# STATE                         object
# ZIP                           object
# X_COORD_PUBLIC               float64
# Y_COORD_PUBLIC               float64
# LATITUDE_PUBLIC              float64
# LONGITUDE_PUBLIC             float64
# DIVISION_ID                   object
# CMPD_PATROL_DIVISION          object
# NPA                            int64
# DATE_REPORTED                 object
# DATE_INCIDENT_BEGAN           object
# DATE_INCIDENT_END             object
# ADDRESS_DESCRIPTION           object
# LOCATION_TYPE_DESCRIPTION     object
# PLACE_TYPE_DESCRIPTION        object
# PLACE_DETAIL_DESCRIPTION      object
# CLEARANCE_STATUS              object
# CLEARANCE_DETAIL_STATUS       object
# CLEARANCE_DATE                object
# ...

# %%
cmpd_data_df = cmpd_data_df.drop('ZIP', axis = 1)

# %%
cmpd_data_df.head(5)
# Out:
#               X              Y  YEAR INCIDENT_REPORT_ID             LOCATION  \
# 0  1.458768e+06  470012.000130  2023   20230130-2148-03     8400 DIANTHUS CT
# 1  1.446976e+06  582067.000101  2023   20230130-2016-02     4200 NAPA OAK DR
# 2  1.449721e+06  543940.999909  2023   20230130-1859-01         300 W 6TH ST
# 3  1.478341e+06  518314.999980  2023   20230130-1858-00  7400 PEBBLESTONE DR
# 4  1.439082e+06  510351.000160  2023   20230130-1820-02        7100 SOUTH BV
#
#         CITY STATE  X_COORD_PUBLIC  Y_COORD_PUBLIC  LATITUDE_PUBLIC  ...  \
# 0  CHARLOTTE    NC       1458768.0        470012.0        35.027901  ...
# 1  CHARLOTTE    NC       1446976.0        582067.0        35.335142  ...
# 2  CHARLOTTE    NC       1449721.0        543941.0        35.230544  ...
# 3  CHARLOTTE    NC       1478341.0        518315.0        35.161565  ...
# 4  CHARLOTTE    NC       1439082.0        510351.0        35.137718  ...
#
# ...

# %%
# Get the columns and the rows that are not null.
cmpd_data_df.count()
# Out:
# X                            537801
# Y                            537801
# YEAR                         557713
# INCIDENT_REPORT_ID           557713
# LOCATION                     557713
# CITY                         557713
# STATE                        557709
# X_COORD_PUBLIC               537801
# Y_COORD_PUBLIC               537801
# LATITUDE_PUBLIC              537801
# LONGITUDE_PUBLIC             537801
# DIVISION_ID                  557713
# CMPD_PATROL_DIVISION         556888
# NPA                          557713
# DATE_REPORTED                557713
# DATE_INCIDENT_BEGAN          557713
# DATE_INCIDENT_END            416938
# ADDRESS_DESCRIPTION          557710
# LOCATION_TYPE_DESCRIPTION    557712
# PLACE_TYPE_DESCRIPTION       557713
# PLACE_DETAIL_DESCRIPTION     557713
# CLEARANCE_STATUS             557713
# CLEARANCE_DETAIL_STATUS      557713
# CLEARANCE_DATE               228499
# HIGHEST_NIBRS_CODE           557713
# HIGHEST_NIBRS_DESCRIPTION    557713
# ...

# %%
# Get the columns and the rows that are not null.
cmpd_data_df.isnull().sum()
# Out:
# X                             19912
# Y                             19912
# YEAR                              0
# INCIDENT_REPORT_ID                0
# LOCATION                          0
# CITY                              0
# STATE                             4
# X_COORD_PUBLIC                19912
# Y_COORD_PUBLIC                19912
# LATITUDE_PUBLIC               19912
# LONGITUDE_PUBLIC              19912
# DIVISION_ID                       0
# CMPD_PATROL_DIVISION            825
# NPA                               0
# DATE_REPORTED                     0
# DATE_INCIDENT_BEGAN               0
# DATE_INCIDENT_END            140775
# ADDRESS_DESCRIPTION               3
# LOCATION_TYPE_DESCRIPTION         1
# PLACE_TYPE_DESCRIPTION            0
# PLACE_DETAIL_DESCRIPTION          0
# CLEARANCE_STATUS                  0
# CLEARANCE_DETAIL_STATUS           0
# CLEARANCE_DATE               329214
# HIGHEST_NIBRS_CODE                0
# HIGHEST_NIBRS_DESCRIPTION         0
# ...

# %%
cmpd_data_df.head(2)
# Out:
#               X              Y  YEAR INCIDENT_REPORT_ID          LOCATION  \
# 0  1.458768e+06  470012.000130  2023   20230130-2148-03  8400 DIANTHUS CT
# 1  1.446976e+06  582067.000101  2023   20230130-2016-02  4200 NAPA OAK DR
#
#         CITY STATE  X_COORD_PUBLIC  Y_COORD_PUBLIC  LATITUDE_PUBLIC  ...  \
# 0  CHARLOTTE    NC       1458768.0        470012.0        35.027901  ...
# 1  CHARLOTTE    NC       1446976.0        582067.0        35.335142  ...
#
#    LOCATION_TYPE_DESCRIPTION PLACE_TYPE_DESCRIPTION  \
# 0                    Indoors            Residential
# 1                Parking Lot            Residential
#
#        PLACE_DETAIL_DESCRIPTION  CLEARANCE_STATUS CLEARANCE_DETAIL_STATUS  \
# 0  Apartment/Duplex Private Res              Open                    Open
# 1  Apartment/Duplex Private Res              Open                    Open
#
#   HIGHEST_NIBRS_CODE    HIGHEST_NIBRS_DESCRIPTION OBJECTID  \
# 0                899  Other Unlisted Non-Criminal        1
# ...

# %%
cmpd_data_df.drop(columns = ['CLEARANCE_DETAIL_STATUS'])
# Out:
#                    X              Y  YEAR INCIDENT_REPORT_ID  \
# 0       1.458768e+06  470012.000130  2023   20230130-2148-03
# 1       1.446976e+06  582067.000101  2023   20230130-2016-02
# 2       1.449721e+06  543940.999909  2023   20230130-1859-01
# 3       1.478341e+06  518314.999980  2023   20230130-1858-00
# 4       1.439082e+06  510351.000160  2023   20230130-1820-02
# ...              ...            ...   ...                ...
# 557708  1.482025e+06  542112.999956  2017   20170101-0025-07
# 557709  1.433072e+06  554945.999881  2017   20170101-0014-05
# 557710  1.445993e+06  479096.000006  2017   20170101-0012-00
# 557711  1.449048e+06  555773.999865  2017   20170101-0011-00
# 557712  1.463804e+06  534795.000157  2017   20170101-0005-01
#
#                            LOCATION       CITY STATE  X_COORD_PUBLIC  \
# 0                  8400 DIANTHUS CT  CHARLOTTE    NC       1458768.0
# 1                  4200 NAPA OAK DR  CHARLOTTE    NC       1446976.0
# ...

# %%
cmpd_data_df.head(3)
# Out:
#               X              Y  YEAR INCIDENT_REPORT_ID          LOCATION  \
# 0  1.458768e+06  470012.000130  2023   20230130-2148-03  8400 DIANTHUS CT
# 1  1.446976e+06  582067.000101  2023   20230130-2016-02  4200 NAPA OAK DR
# 2  1.449721e+06  543940.999909  2023   20230130-1859-01      300 W 6TH ST
#
#         CITY STATE  X_COORD_PUBLIC  Y_COORD_PUBLIC  LATITUDE_PUBLIC  ...  \
# 0  CHARLOTTE    NC       1458768.0        470012.0        35.027901  ...
# 1  CHARLOTTE    NC       1446976.0        582067.0        35.335142  ...
# 2  CHARLOTTE    NC       1449721.0        543941.0        35.230544  ...
#
#    LOCATION_TYPE_DESCRIPTION PLACE_TYPE_DESCRIPTION  \
# 0                    Indoors            Residential
# 1                Parking Lot            Residential
# 2                    Indoors                 Retail
#
#        PLACE_DETAIL_DESCRIPTION   CLEARANCE_STATUS CLEARANCE_DETAIL_STATUS  \
# 0  Apartment/Duplex Private Res               Open                    Open
# ...

# %%
# Drop all rows with NaN values
cmpd_data_df_clean = cmpd_data_df.dropna()
cmpd_data_df_clean

# %%
cmpd_data_df.isna().sum()
# Out:
# X                             19912
# Y                             19912
# YEAR                              0
# INCIDENT_REPORT_ID                0
# LOCATION                          0
# CITY                              0
# STATE                             4
# X_COORD_PUBLIC                19912
# Y_COORD_PUBLIC                19912
# LATITUDE_PUBLIC               19912
# LONGITUDE_PUBLIC              19912
# DIVISION_ID                       0
# CMPD_PATROL_DIVISION            825
# NPA                               0
# DATE_REPORTED                     0
# DATE_INCIDENT_BEGAN               0
# ADDRESS_DESCRIPTION               3
# LOCATION_TYPE_DESCRIPTION         1
# PLACE_TYPE_DESCRIPTION            0
# PLACE_DETAIL_DESCRIPTION          0
# CLEARANCE_STATUS                  0
# CLEARANCE_DETAIL_STATUS           0
# HIGHEST_NIBRS_CODE                0
# HIGHEST_NIBRS_DESCRIPTION         0
# OBJECTID                          0
# GlobalID                          0
# ...

# %%
# Drop all rows with NaN values
cmpd_data_df_clean = cmpd_data_df.dropna()
cmpd_data_df_clean = cmpd_data_df.dropna(axis=0)
cmpd_data_df_clean.head(3)
# Out:
#               X              Y  YEAR INCIDENT_REPORT_ID          LOCATION  \
# 0  1.458768e+06  470012.000130  2023   20230130-2148-03  8400 DIANTHUS CT
# 1  1.446976e+06  582067.000101  2023   20230130-2016-02  4200 NAPA OAK DR
# 2  1.449721e+06  543940.999909  2023   20230130-1859-01      300 W 6TH ST
#
#         CITY STATE  X_COORD_PUBLIC  Y_COORD_PUBLIC  LATITUDE_PUBLIC  ...  \
# 0  CHARLOTTE    NC       1458768.0        470012.0        35.027901  ...
# 1  CHARLOTTE    NC       1446976.0        582067.0        35.335142  ...
# 2  CHARLOTTE    NC       1449721.0        543941.0        35.230544  ...
#
#       ADDRESS_DESCRIPTION LOCATION_TYPE_DESCRIPTION PLACE_TYPE_DESCRIPTION  \
# 0  Location of occurrence                   Indoors            Residential
# 1  Location of occurrence               Parking Lot            Residential
# 2  Location of occurrence                   Indoors                 Retail
#
# ...

# %%
cmpd_data_df_clean.isna().sum()
# Out:
# X                            0
# Y                            0
# YEAR                         0
# INCIDENT_REPORT_ID           0
# LOCATION                     0
# CITY                         0
# STATE                        0
# X_COORD_PUBLIC               0
# Y_COORD_PUBLIC               0
# LATITUDE_PUBLIC              0
# LONGITUDE_PUBLIC             0
# DIVISION_ID                  0
# CMPD_PATROL_DIVISION         0
# NPA                          0
# DATE_REPORTED                0
# DATE_INCIDENT_BEGAN          0
# ADDRESS_DESCRIPTION          0
# LOCATION_TYPE_DESCRIPTION    0
# PLACE_TYPE_DESCRIPTION       0
# PLACE_DETAIL_DESCRIPTION     0
# CLEARANCE_STATUS             0
# CLEARANCE_DETAIL_STATUS      0
# HIGHEST_NIBRS_CODE           0
# HIGHEST_NIBRS_DESCRIPTION    0
# OBJECTID                     0
# GlobalID                     0
# dtype: int64

# %%
# Get the unique values of the type of city.
cmpd_data_df.describe()
# Out:
#                   X              Y           YEAR  X_COORD_PUBLIC  \
# count  5.378010e+05  537801.000000  557713.000000    5.378010e+05
# mean   1.453964e+06  541306.701151    2019.531366    1.453964e+06
# std    2.222391e+04   25138.646549       1.752172    2.222391e+04
# min    1.384875e+06  465419.000129    2017.000000    1.384875e+06
# 25%    1.438422e+06  525439.999838    2018.000000    1.438422e+06
# 50%    1.452160e+06  542000.999852    2019.000000    1.452160e+06
# 75%    1.471971e+06  558146.000042    2021.000000    1.471971e+06
# max    1.535404e+06  645111.999995    2023.000000    1.535404e+06
#
#        Y_COORD_PUBLIC  LATITUDE_PUBLIC  LONGITUDE_PUBLIC            NPA  \
# count   537801.000000    537801.000000     537801.000000  557713.000000
# mean    541306.701150        35.219832        -80.828457     206.060741
# std      25138.646549         0.656145          0.074068     124.885857
# min     465419.000000       -80.963592        -81.055860       0.000000
# ...

# %%
# Get the columns and the rows that are not null.
cmpd_data_df_clean.count()
# Out:
# X                            537294
# Y                            537294
# YEAR                         537294
# INCIDENT_REPORT_ID           537294
# LOCATION                     537294
# CITY                         537294
# STATE                        537294
# X_COORD_PUBLIC               537294
# Y_COORD_PUBLIC               537294
# LATITUDE_PUBLIC              537294
# LONGITUDE_PUBLIC             537294
# DIVISION_ID                  537294
# CMPD_PATROL_DIVISION         537294
# NPA                          537294
# DATE_REPORTED                537294
# DATE_INCIDENT_BEGAN          537294
# ADDRESS_DESCRIPTION          537294
# LOCATION_TYPE_DESCRIPTION    537294
# PLACE_TYPE_DESCRIPTION       537294
# PLACE_DETAIL_DESCRIPTION     537294
# CLEARANCE_STATUS             537294
# CLEARANCE_DETAIL_STATUS      537294
# HIGHEST_NIBRS_CODE           537294
# HIGHEST_NIBRS_DESCRIPTION    537294
# OBJECTID                     537294
# GlobalID                     537294
# ...

# %%
# Get the data types of each column.
cmpd_data_df_clean.dtypes
# Out:
# X                            float64
# Y                            float64
# YEAR                           int64
# INCIDENT_REPORT_ID            object
# LOCATION                      object
# CITY                          object
# STATE                         object
# X_COORD_PUBLIC               float64
# Y_COORD_PUBLIC               float64
# LATITUDE_PUBLIC              float64
# LONGITUDE_PUBLIC             float64
# DIVISION_ID                   object
# CMPD_PATROL_DIVISION          object
# NPA                            int64
# DATE_REPORTED                 object
# DATE_INCIDENT_BEGAN           object
# ADDRESS_DESCRIPTION           object
# LOCATION_TYPE_DESCRIPTION     object
# PLACE_TYPE_DESCRIPTION        object
# PLACE_DETAIL_DESCRIPTION      object
# CLEARANCE_STATUS              object
# CLEARANCE_DETAIL_STATUS       object
# HIGHEST_NIBRS_CODE            object
# HIGHEST_NIBRS_DESCRIPTION     object
# OBJECTID                       int64
# ...
